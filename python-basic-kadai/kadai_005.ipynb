# %% [markdown]
# # 【課題】変数を使って四則演算しよう

# %%
johen = 10

# %%
kahen = 20

# %%
takasa = 5

# %%
daikei_menseki = (johen+kahen)*takasa/2 #公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2

# %%
print(f'{daikei_menseki}cm²') #出力結果は「◯◯cm²」となるように単位をつけてください。
# Out:
# 75.0cm²
